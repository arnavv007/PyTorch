# %%
import torch
from torch import nn # torch.nn contains all of PyTorch's  building blocks for neural networks
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 4
#       2 from torch import nn # torch.nn contains all of PyTorch's  building blocks for neural networks
#       3 import matplotlib.pyplot as plt
# ----> 4 from google.colab import files
#
# ModuleNotFoundError: No module named 'google'

# %% [markdown]
# # PyTorch Workflow

# %%
what_we_are_covering = {1: "data(prepare and load)",
                        2: "Build model",
                        3: "fitting the model to data (training)",
                        4: "Making predictions and evaluating a model (inference)",
                        5: "Saving and loading a model",
                        6: "Putting it all together"}

what_we_are_covering
# Out:
# {1: 'data(prepare and load)',
#  2: 'Build model',
#  3: 'fitting the model to data (training)',
#  4: 'Making predictions and evaluating a model (inference)',
#  5: 'Saving and loading a model',
#  6: 'Putting it all together'}

# %% [markdown]
# ## 1. Data (preparing and loading):

# %%
# Creating some known data using linear regression formula:
weight = 0.7
bias = 0.3

# Create
start = 0
end = 1
step = 0.02
X = torch.arange(start, end, step).unsqueeze(dim=1)
y = weight * X + bias

X[:10], y[:10], len(X), len(y)
# Out:
# (tensor([[0.0000],
#          [0.0200],
#          [0.0400],
#          [0.0600],
#          [0.0800],
#          [0.1000],
#          [0.1200],
#          [0.1400],
#          [0.1600],
#          [0.1800]]),
#  tensor([[0.3000],
#          [0.3140],
#          [0.3280],
#          [0.3420],
#          [0.3560],
#          [0.3700],
#          [0.3840],
#          [0.3980],
#          [0.4120],
#          [0.4260]]),
#  50,
#  50)

# %% [markdown]
# ### Summary
# Date - 29/Mar/2026
#
# --------------------------------------------------------------------------------------------------
# #### About the Linear Regression formula:
# `y = mx + b`
# <pre>
# Where:
# y = dependent variable
# m = Slope of the line
# x = independent variable
# b = bias
# </pre>
# This formula creates a line as you can see in the image:<br><br>
# <img src = "images/desmos.png" width = "800">
# <br>
#
# ##### **What we will do?**
# 1. We will get the data as points on the graph
# 2. We will create a line (Let's say parallel to the x-axis initially)
# 3. We will slowly change the slope of the line and use bias to either lift it up or down, so that it best represents the points.
# 4. Now the line is created and it predicts future points (approximation)
# <br><br>
#
# <img src = "images/LinearRegression.png" width = "800">
