# %%
import torch

# %% [markdown]
# ### Random Tensors
#
# Why random Tensors?
#
# Random tensors are important because the way many neural netowrks learn is that they start with tensors full of random numbers and then adjust those random numbers to better represent the data
#
# `Start with random numbers -> look at data -> update random numbers -> look at data -> update random numbers...`

# %%
# Create a random tensor of size (3,4):
random_tensor = torch.rand(3,5)
random_tensor
# Out:
# tensor([[0.5401, 0.8582, 0.8553, 0.5908, 0.4895],
#         [0.9199, 0.8536, 0.3349, 0.6277, 0.3131],
#         [0.7113, 0.2633, 0.1170, 0.6310, 0.7472]])

# %%
random_tensor.ndim
# Out:
# 2

# %%
# Create a random tensor with similar shape to an image tensor
random_image_size_tensor = torch.rand(size=(3,224,224)) # color channels (r,g,b), Heigt, width
random_image_size_tensor.shape, random_image_size_tensor.ndim
# Out:
# (torch.Size([3, 224, 224]), 3)

# %% [markdown]
# ##### Exercise

# %%
TENSOR = torch.rand(1,2,3,4)
print(TENSOR)
print(f"\nNumber of Dimensions of Tensor : {TENSOR.ndim}")
# Out:
# tensor([[[[0.8154, 0.4937, 0.4146, 0.7744],
#           [0.4732, 0.9363, 0.6113, 0.4974],
#           [0.6186, 0.7492, 0.3957, 0.1015]],
#
#          [[0.3680, 0.8387, 0.6209, 0.1138],
#           [0.0642, 0.6525, 0.1388, 0.9589],
#           [0.1609, 0.9161, 0.5348, 0.9076]]]])
#
# Number of Dimensions of Tensor : 4

# %%
IMAGE_TENSOR = torch.rand(size=(100, 100, 3))
IMAGE_TENSOR, IMAGE_TENSOR.shape, IMAGE_TENSOR.dtype
# Out:
# (tensor([[[0.9887, 0.2805, 0.7178],
#           [0.2635, 0.8806, 0.6846],
#           [0.8958, 0.4884, 0.9332],
#           ...,
#           [0.3377, 0.3065, 0.8430],
#           [0.7721, 0.3834, 0.3302],
#           [0.7404, 0.2158, 0.4045]],
#
#          [[0.3765, 0.4522, 0.3525],
#           [0.1825, 0.3988, 0.8001],
#           [0.4616, 0.9967, 0.3816],
#           ...,
#           [0.2339, 0.3836, 0.4169],
#           [0.6426, 0.0204, 0.5462],
#           [0.9305, 0.5922, 0.2795]],
#
#          [[0.0324, 0.8122, 0.7205],
#           [0.6146, 0.1837, 0.4212],
#           [0.7164, 0.6185, 0.0692],
#           ...,
#           [0.1991, 0.6119, 0.2232],
#           [0.8217, 0.9840, 0.7694],
#           [0.2144, 0.8833, 0.1138]],
#
#          ...,
#
#          [[0.5815, 0.3841, 0.6733],
#           [0.3168, 0.4380, 0.6815],
#           [0.8426, 0.9486, 0.5235],
#           ...,
#           [0.3579, 0.9323, 0.8438],
#           [0.3342, 0.1602, 0.4287],
# ...

# %% [markdown]
# ### Summary:

# %%
"""
Date - 13/Mar/2026
---------------------------------------------------------------------------------------------

Random Tensors are used because it's very tiring to right tensors(to train your model) by hand. One can create these random tensors and let the model train. The model will automatically adjust the parameters. 

----------------------------------------------------------------------------------------------

    Attribute                                    Function
torch.rand(*size)                   Creates a random Tensor of the given size  
    .dtype                   Returns the type of the data(e.g. float, integer, etc.)

----------------------------------------------------------------------------------------------

When Creating a tensor for image, the number of dimensions is 3.
Image_Tensor = (h, b, c) -> Example
h = height
b = breadth
c = color channels (e.g. red, green, blue)

----------------------------------------------------------------------------------------------

Question:
Is there any difference between writing -
TENSOR = torch.rand(3,4)
and
TENSOR = torch.rand(size=(3,4))
and 
TENSOR = torch.rand(*(3,4))?

Answer:
No. All results same.
Note - Using '*' might be useful in cases like:
        shape = (3,4)
        TENSOR = torch.rand(*shape)
"""
# Out:
# "\nDate - 13/Mar/2026\n---------------------------------------------------------------------------------------------\n\nRandom Tensors are used because it's very tiring to right tensors(to train your model) by hand. One can create these random tensors and let the model train. The model will automatically adjust the parameters. \n\n----------------------------------------------------------------------------------------------\n\n    Attribute                                    Function\ntorch.rand(*size)                   Creates a random Tensor of the given size  \n    .dtype                   Returns the type of the data(e.g. float, integer, etc.)\n\n----------------------------------------------------------------------------------------------\n\nWhen Creating a tensor for image, the number of dimensions is 3.\nImage_Tensor = (h, b, c) -> Example\nh = height\nb = breadth\nc = color channels (e.g. red, green, blue)\n\n-------------------------------------------------------------------
# ...
