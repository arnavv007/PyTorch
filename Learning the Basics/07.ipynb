# %%
import torch

# %% [markdown]
# ### One of the most common errors in deep learning: shape error

# %%
# Shapes for matrix multiplication
tensor_A = torch.tensor([[1,2],
                        [2,3],
                        [3,4]])

tensor_B = torch.tensor([[7,10],
                         [8,11],
                         [12, 13]])
# It will throw a shape error
torch.mm(tensor_A, tensor_B) # torch.mm = torch.matmul
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 10
#       2 tensor_A = torch.tensor([[1,2],
#       3                         [2,3],
#       4                         [3,4]])
#       6 tensor_B = torch.tensor([[7,10],
#       7                          [8,11],
#       8                          [12, 13]])
# ---> 10 torch.mm(tensor_A, tensor_B) # torch.mm = torch.matmul
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (3x2 and 3x2)

# %%
tensor_A.shape, tensor_B.shape
# Out:
# (torch.Size([3, 2]), torch.Size([3, 2]))

# %% [markdown]
# To fix our tensor shape issues, we can manipulate the shape of one of our tensors using transpose
#
# A **transpose** switches the axes or dimensions of a given tensor

# %%
tensor_B.T, tensor_B.T.shape
# Out:
# (tensor([[ 7,  8, 12],
#          [10, 11, 13]]),
#  torch.Size([2, 3]))

# %%
# The matrix multiplication operation works when Tensor_b is transposed
print(f"Original shapes : tensor_A = {tensor_A.shape}, tensor_B = {tensor_B.shape}")
print(f"New shapes: tensor_A = {tensor_A.shape}, tensor_b = {tensor_B.T.shape}")
print(f"Multiplying : {tensor_A.shape} @ {tensor_B.T.shape} <- inner dimensions must match")
print("Output:\n")
output = torch.matmul(tensor_A, tensor_B.T)
print(output)
print(f"\nOutput shape: {output.shape}")
# Out:
# Original shapes : tensor_A = torch.Size([3, 2]), tensor_B = torch.Size([3, 2])
# New shapes: tensor_A = torch.Size([3, 2]), tensor_b = torch.Size([2, 3])
# Multiplying : torch.Size([3, 2]) @ torch.Size([2, 3]) <- inner dimensions must match
# Output:
#
# tensor([[27, 30, 38],
#         [44, 49, 63],
#         [61, 68, 88]])
#
# Output shape: torch.Size([3, 3])

# %%
tensor_A.T, tensor_A.shape, tensor_A.T.shape
# Out:
# (tensor([[1, 2, 3],
#          [2, 3, 4]]),
#  torch.Size([3, 2]),
#  torch.Size([2, 3]))

# %%
tensor_C = torch.tensor([
                          [
                            [1,2,3],
                            [4,5,6]
                          ]
                        ])
tensor_C.shape, tensor_C.T.shape
# Out:
# (torch.Size([1, 2, 3]), torch.Size([3, 2, 1]))

# %% [markdown]
# ### Summary
#
# Date - 18/Mar/2026
#
# --------------------------------------------------------------------------------------------------
# <pre>
# Functions                                          Meaning
#
# tensor.T               Flips the shape of a tensor(e.g. if a tensor has the shape of (1,2,3),
#                                   then it will make it the shape of (3,2,1))
#
# torch.mm(A, B)             Same as torch.matmul(). It is used for matrix multiplication
# </pre>
