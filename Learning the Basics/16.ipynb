# %%
import torch

# %% [markdown]
# ### 3. Putting tensors (and models) on the GPU
# The reason we want out tensors/models on the GPU is because using a GPU results in faster computations.

# %%
# Create a tensor (default on the CPU)
tensor = torch.tensor([1,2,3], device="cpu")

#Tensor not on GPU
print(tensor, tensor.device)
# Out:
# tensor([1, 2, 3]) cpu

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
tensor_on_gpu = tensor.to(device)
tensor_on_gpu
# Out:
# tensor([1, 2, 3], device='cuda:0')

# %% [markdown]
# ### 4. Moving Tensors back to CPU

# %%
# If you want to use NumPy for your tensors, then you'll have to shift to CPU, because NumPy can't leverage with GPU...
tensor_on_gpu.numpy() # -> It will throw an error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5961/2421105929.py in <cell line: 0>()
#       1 # If you want to use NumPy for your tensors, then you'll have to shift to CPU, because NumPy can't leverage with GPU...
# ----> 2 tensor_on_gpu.numpy() # -> It will throw an error
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.

# %%
tensor_back_on_CPU = tensor_on_gpu.cpu().numpy()
tensor_back_on_CPU, tensor_back_on_CPU.device
# Out:
# (array([1, 2, 3]), 'cpu')
